# %% [markdown]
# # Earliest Tip vs Ancestral State
#
# For each simulation in a dataset, check whether the **earliest sampled tip**
# (the tip with the smallest forward time in the BEAST2 tree) belongs to the
# same location as the **ancestral state** (the outbreak origin labeled in `*_nf.csv`).
#
# Reports the match rate per dataset.

# %%
import re
import csv
from pathlib import Path

# Tip annotation: [&type="I{LOC}",samp="sample",time=T]
TIP_RE = re.compile(r'\[&type="I\{(\d+)\}",samp="sample",time=([\d.]+)\]')
TREE_RE = re.compile(r'tree STATE_\d+ = (.+?)\n')


def earliest_tip_location(trees_path):
    """Location (int) of the earliest sampled tip in the first tree."""
    tree_str = TREE_RE.search(Path(trees_path).read_text()).group(1)
    loc, _ = min(TIP_RE.findall(tree_str), key=lambda x: float(x[1]))
    return int(loc)


def ancestral_state_location(nf_path):
    """Location (int) where Ancestral_State == 1."""
    with open(nf_path) as f:
        for row in csv.DictReader(f):
            if row['Ancestral_State'] == '1':
                return int(row['Location'])
    return None


def match_rate(dataset_dir):
    """Fraction of simulations where earliest tip == ancestral state."""
    dataset_dir = Path(dataset_dir)
    matches, total = 0, 0
    for tf in sorted(dataset_dir.glob('*_beast2.trees')):
        nf = dataset_dir / f'{tf.name.replace("_beast2.trees", "")}_nf.csv'
        if not nf.exists():
            continue
        matches += earliest_tip_location(tf) == ancestral_state_location(nf)
        total += 1
    return matches, total

# %%
datasets = [
    '/Users/lukelyu/Desktop/epidata/1000_1_0.0006_0.0007/',
    '/Users/lukelyu/Desktop/epidata/1000_1_0.0006_0.0015/',
    '/Users/lukelyu/Desktop/epidata/1000_1_0.0006_0.0023/',
    '/Users/lukelyu/Desktop/epidata/1000_1_0.0003_0.0015/',
    '/Users/lukelyu/Desktop/epidata/1000_1_0.0015_0.0015/'
    # add more dataset paths here
]

for ds in datasets:
    matches, total = match_rate(ds)
    print(f'{Path(ds).name:40s}  {matches}/{total}  ({matches/total:.2%})')
# Out:
# 1000_1_0.0006_0.0007                      777/1000  (77.70%)
# 1000_1_0.0006_0.0015                      648/1000  (64.80%)
# 1000_1_0.0006_0.0023                      533/1000  (53.30%)
# 1000_1_0.0003_0.0015                      516/1000  (51.60%)
# 1000_1_0.0015_0.0015                      715/1000  (71.50%)

# %%
import numpy as np


def tree_sizes(dataset_dir):
    """Number of tips in the first tree of each simulation."""
    dataset_dir = Path(dataset_dir)
    sizes = []
    for tf in sorted(dataset_dir.glob('*_beast2.trees')):
        tree_str = TREE_RE.search(tf.read_text()).group(1)
        sizes.append(len(TIP_RE.findall(tree_str)))
    return np.array(sizes)


print(f'{"Dataset":40s}  {"Min":>5s}  {"Mean":>7s}  {"Max":>5s}  {"Std":>7s}  {"N":>5s}')
print('-' * 75)
for ds in datasets:
    sz = tree_sizes(ds)
    print(f'{Path(ds).name:40s}  {sz.min():5d}  {sz.mean():7.1f}  {sz.max():5d}  {sz.std():7.2f}  {len(sz):5d}')
# Out:
# Dataset                                     Min     Mean    Max      Std      N
# ---------------------------------------------------------------------------
# 1000_1_0.0006_0.0007                        432    955.6   2081   312.33   1000
# 1000_1_0.0006_0.0015                        405    927.2   1993   317.99   1000
# 1000_1_0.0006_0.0023                        410    932.1   2069   315.25   1000
# 1000_1_0.0003_0.0015                        302    564.7   1135   146.17   1000
# 1000_1_0.0015_0.0015                        736   2192.9   4863   756.64   1000

# %%
def sampling_rates(dataset_dir):
    """Sampling rate = tree size / sum of Accumulated_Infections across locations."""
    dataset_dir = Path(dataset_dir)
    rates = []
    for tf in sorted(dataset_dir.glob('*_beast2.trees')):
        nf = dataset_dir / f'{tf.name.replace("_beast2.trees", "")}_nf.csv'
        if not nf.exists():
            continue
        tree_str = TREE_RE.search(tf.read_text()).group(1)
        n_tips = len(TIP_RE.findall(tree_str))
        with open(nf) as f:
            total_infections = sum(int(row['Accumulated_Infections']) for row in csv.DictReader(f))
        rates.append(n_tips / total_infections)
    return np.array(rates)


print(f'{"Dataset":40s}  {"Min":>8s}  {"Mean":>8s}  {"Max":>8s}  {"Std":>8s}  {"N":>5s}')
print('-' * 80)
for ds in datasets:
    r = sampling_rates(ds)
    print(f'{Path(ds).name:40s}  {r.min():8.4f}  {r.mean():8.4f}  {r.max():8.4f}  {r.std():8.4f}  {len(r):5d}')
# Out:
# Dataset                                        Min      Mean       Max       Std      N
# --------------------------------------------------------------------------------
# 1000_1_0.0006_0.0007                        0.0096    0.0179    0.0313    0.0044   1000
# 1000_1_0.0006_0.0015                        0.0094    0.0148    0.0238    0.0033   1000
# 1000_1_0.0006_0.0023                        0.0076    0.0129    0.0193    0.0025   1000
# 1000_1_0.0003_0.0015                        0.0050    0.0084    0.0121    0.0015   1000
# 1000_1_0.0015_0.0015                        0.0163    0.0356    0.0557    0.0078   1000

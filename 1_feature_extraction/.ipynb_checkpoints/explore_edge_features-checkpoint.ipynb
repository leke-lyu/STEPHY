# %% [markdown]
# # Edge Features Explorer
#
# This notebook explores edge features from phylogenetic graph data.
# For each edge in a specified graph, we analyze the distribution of feature values.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for better-looking plots
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 8)

# %% [markdown]
# ## Configuration
#
# Set the path to your edge CSV file and the graph_id to analyze.

# %%
# Configuration
edge_file_path = "/Users/lukelyu/Desktop/epidata/100_10_new/1_edge.csv"
target_graph_id = "0_2"  # Change this to explore different graphs

# %% [markdown]
# ## Load and Parse Data

# %%
# Load the CSV file
df = pd.read_csv(edge_file_path)

print(f"Total edges in file: {len(df)}")
print(f"Unique graph IDs: {df['graph_id'].nunique()}")
print(f"\nFirst few rows:")
df.head()

# %%
# Filter by target graph_id
df_filtered = df[df['graph_id'] == target_graph_id].copy()

print(f"Number of edges in graph '{target_graph_id}': {len(df_filtered)}")

if len(df_filtered) == 0:
    print(f"\nWarning: No edges found for graph_id '{target_graph_id}'")
    print(f"Available graph_ids: {sorted(df['graph_id'].unique())}")

# %%
def parse_edge_features(feature_string):
    """
    Parse edge features from string format.
    The features are stored as [value1\tvalue2\tvalue3...]
    """
    # Remove brackets and split by tab or whitespace
    feature_string = str(feature_string).strip()
    if feature_string.startswith('['):
        feature_string = feature_string[1:]
    if feature_string.endswith(']'):
        feature_string = feature_string[:-1]
    
    # Split by tab or whitespace and convert to float
    values = [float(x.strip()) for x in feature_string.split() if x.strip()]
    return np.array(values)

# Parse edge features for filtered data
df_filtered['features_array'] = df_filtered['edge_features'].apply(parse_edge_features)

# Check parsing
if len(df_filtered) > 0:
    print(f"Example edge features (first edge):")
    print(f"  Length: {len(df_filtered.iloc[0]['features_array'])}")
    print(f"  First 10 values: {df_filtered.iloc[0]['features_array'][:10]}")

# %% [markdown]
# ## Calculate Statistics for Each Edge

# %%
def calculate_statistics(features_array):
    """
    Calculate min, 25%, median, 75%, max for a feature array.
    """
    return {
        'min': np.min(features_array),
        'q25': np.percentile(features_array, 25),
        'median': np.median(features_array),
        'q75': np.percentile(features_array, 75),
        'max': np.max(features_array)
    }

# Calculate statistics for each edge
stats_list = []
for idx, row in df_filtered.iterrows():
    stats = calculate_statistics(row['features_array'])
    stats['edge_label'] = f"{row['node1']}-{row['node2']}"
    stats['node1'] = row['node1']
    stats['node2'] = row['node2']
    stats['feature_count'] = len(row['features_array'])
    stats_list.append(stats)

stats_df = pd.DataFrame(stats_list)

print(f"\nStatistics for {len(stats_df)} edges:")
stats_df

# %% [markdown]
# ## Visualizations

# %%
# Plot 1: Box plot representation for each edge
fig, ax = plt.subplots(figsize=(16, 8))

# Create box plot data manually
positions = range(len(stats_df))
box_data = []

for idx, row in stats_df.iterrows():
    # Create a box plot with our statistics
    box_data.append([row['min'], row['q25'], row['median'], row['q75'], row['max']])

# Use bxp for custom box plot
bp_dicts = []
for i, (pos, data) in enumerate(zip(positions, box_data)):
    bp_dict = {
        'label': stats_df.iloc[i]['edge_label'],
        'whislo': data[0],  # min
        'q1': data[1],      # 25%
        'med': data[2],     # median
        'q3': data[3],      # 75%
        'whishi': data[4],  # max
        'fliers': []        # no outliers in this representation
    }
    bp_dicts.append(bp_dict)

bp = ax.bxp(bp_dicts, positions=positions, widths=0.6, 
            patch_artist=True, showfliers=False)

# Customize colors
for patch in bp['boxes']:
    patch.set_facecolor('lightblue')
    patch.set_alpha(0.7)

ax.set_xlabel('Edge', fontsize=12, fontweight='bold')
ax.set_ylabel('Feature Value', fontsize=12, fontweight='bold')
ax.set_title(f'Edge Feature Distribution Statistics for Graph {target_graph_id}', 
             fontsize=14, fontweight='bold')
ax.set_xticks(positions)
ax.set_xticklabels(stats_df['edge_label'], rotation=45, ha='right')
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Plot 2: Line plot showing the 5 statistics across edges
fig, ax = plt.subplots(figsize=(16, 8))

x_pos = range(len(stats_df))

ax.plot(x_pos, stats_df['min'], marker='o', label='Min', linewidth=2, markersize=6)
ax.plot(x_pos, stats_df['q25'], marker='s', label='25th Percentile', linewidth=2, markersize=6)
ax.plot(x_pos, stats_df['median'], marker='^', label='Median', linewidth=2.5, markersize=7)
ax.plot(x_pos, stats_df['q75'], marker='D', label='75th Percentile', linewidth=2, markersize=6)
ax.plot(x_pos, stats_df['max'], marker='v', label='Max', linewidth=2, markersize=6)

ax.set_xlabel('Edge', fontsize=12, fontweight='bold')
ax.set_ylabel('Feature Value', fontsize=12, fontweight='bold')
ax.set_title(f'Edge Feature Statistics Across Edges for Graph {target_graph_id}', 
             fontsize=14, fontweight='bold')
ax.set_xticks(x_pos)
ax.set_xticklabels(stats_df['edge_label'], rotation=45, ha='right')
ax.legend(loc='best', fontsize=10)
ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Plot 3: Heatmap of statistics
fig, ax = plt.subplots(figsize=(12, len(stats_df) * 0.5 + 2))

# Prepare data for heatmap
heatmap_data = stats_df[['min', 'q25', 'median', 'q75', 'max']].T
heatmap_data.columns = stats_df['edge_label']

sns.heatmap(heatmap_data, annot=True, fmt='.1f', cmap='YlOrRd', 
            cbar_kws={'label': 'Feature Value'}, ax=ax)

ax.set_xlabel('Edge', fontsize=12, fontweight='bold')
ax.set_ylabel('Statistic', fontsize=12, fontweight='bold')
ax.set_title(f'Edge Feature Statistics Heatmap for Graph {target_graph_id}', 
             fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# Plot 4: Interquartile range (IQR) visualization
fig, ax = plt.subplots(figsize=(16, 8))

stats_df['iqr'] = stats_df['q75'] - stats_df['q25']
stats_df['range'] = stats_df['max'] - stats_df['min']

x_pos = range(len(stats_df))
width = 0.35

bars1 = ax.bar([x - width/2 for x in x_pos], stats_df['iqr'], width, 
               label='IQR (Q75-Q25)', alpha=0.8, color='steelblue')
bars2 = ax.bar([x + width/2 for x in x_pos], stats_df['range'], width, 
               label='Range (Max-Min)', alpha=0.8, color='coral')

ax.set_xlabel('Edge', fontsize=12, fontweight='bold')
ax.set_ylabel('Value', fontsize=12, fontweight='bold')
ax.set_title(f'IQR and Range Comparison for Graph {target_graph_id}', 
             fontsize=14, fontweight='bold')
ax.set_xticks(x_pos)
ax.set_xticklabels(stats_df['edge_label'], rotation=45, ha='right')
ax.legend(fontsize=10)
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary Statistics Table

# %%
# Display comprehensive summary
print(f"\n{'='*80}")
print(f"Summary for Graph: {target_graph_id}")
print(f"{'='*80}\n")
print(f"Total number of edges: {len(stats_df)}")
print(f"\nFeature count per edge:")
print(stats_df[['edge_label', 'feature_count']].to_string(index=False))
print(f"\n\nStatistics across all edges:")
stats_df[['edge_label', 'min', 'q25', 'median', 'q75', 'max']].round(2)

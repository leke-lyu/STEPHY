# %% [markdown]
# # Edge Features Explorer
#
# This notebook explores edge features from phylogenetic graph data.
# For each edge in a specified graph, we analyze the distribution of feature values.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for better-looking plots
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 8)

# %% [markdown]
# ## Configuration
#
# Set the path to your edge CSV file and the graph_id to analyze.

# %%
# Configuration
edge_file_path = "/Users/lukelyu/Desktop/epidata/test_3_files/0_edge.csv"
target_graph_id = "0_0"  # Change this to explore different graphs

# %% [markdown]
# ## Load and Parse Data

# %%
# Load the CSV file
df = pd.read_csv(edge_file_path)

print(f"Total edges in file: {len(df)}")
print(f"Unique graph IDs: {df['graph_id'].nunique()}")
# Out:
# Total edges in file: 1000
# Unique graph IDs: 10

# %%
# Filter by target graph_id
df_filtered = df[df['graph_id'] == target_graph_id].copy()

print(f"Number of edges in graph '{target_graph_id}': {len(df_filtered)}")

if len(df_filtered) == 0:
    print(f"\nWarning: No edges found for graph_id '{target_graph_id}'")
    print(f"Available graph_ids: {sorted(df['graph_id'].unique())}")
# Out:
# Number of edges in graph '0_0': 100

# %%
def parse_patristic_distances(distance_string):
    """
    Parse patristic distances from string format.
    Returns None if the string is empty or invalid.
    """
    distance_string = str(distance_string).strip()
    
    # Check if empty or nan
    if not distance_string or distance_string.lower() == 'nan' or distance_string == '':
        return None
    
    # Remove brackets
    if distance_string.startswith('['):
        distance_string = distance_string[1:]
    if distance_string.endswith(']'):
        distance_string = distance_string[:-1]
    
    # Split by whitespace and convert to float
    try:
        values = [float(x.strip()) for x in distance_string.split() if x.strip()]
        if len(values) == 0:
            return None
        return np.array(values)
    except:
        return None

# Parse patristic distances for filtered data
df_filtered['distances_array'] = df_filtered['patristic_distance'].apply(parse_patristic_distances)

# Filter out edges with invalid/empty patristic distances
original_count = len(df_filtered)
df_filtered = df_filtered[df_filtered['distances_array'].notna()].copy()
dropped_count = original_count - len(df_filtered)

print(f"Total edges in graph '{target_graph_id}': {original_count}")
if dropped_count > 0:
    print(f"Dropped {dropped_count} edges with missing/invalid patristic_distance")
print(f"Valid edges for analysis: {len(df_filtered)}")
# Out:
# Total edges in graph '0_0': 100
# Dropped 19 edges with missing/invalid patristic_distance
# Valid edges for analysis: 81
#
# Example patristic distances (first edge):
#   Edge: 1-1
#   Length: 28
#   First 10 values: [ 74.53682797  74.65615062  74.69494339 105.97237857 112.32422419
#  125.00985255 128.18557156 128.30489421 129.96658817 130.61654082]

# %% [markdown]
# ## Calculate Statistics for Each Edge

# %%
def calculate_statistics(distances_array):
    """
    Calculate min, 25%, median, 75%, max for a distance array.
    """
    return {
        'min': np.min(distances_array),
        'q25': np.percentile(distances_array, 25),
        'median': np.median(distances_array),
        'q75': np.percentile(distances_array, 75),
        'max': np.max(distances_array)
    }

# Calculate statistics for each edge
stats_list = []
for idx, row in df_filtered.iterrows():
    stats = calculate_statistics(row['distances_array'])
    stats['edge_label'] = f"{row['src']}-{row['dst']}"
    stats['src'] = row['src']
    stats['dst'] = row['dst']
    stats['distance_count'] = len(row['distances_array'])
    stats_list.append(stats)

stats_df = pd.DataFrame(stats_list)

# %% [markdown]
# ## Visualizations

# %%
# Sort stats_df by minimum value
stats_df_sorted = stats_df.sort_values('min').reset_index(drop=True)

# Box plot representation for each edge (sorted by min)
fig, ax = plt.subplots(figsize=(16, 8))

# Create box plot data manually using sorted dataframe
positions = range(len(stats_df_sorted))
box_data = []

for idx, row in stats_df_sorted.iterrows():
    # Create a box plot with our statistics
    box_data.append([row['min'], row['q25'], row['median'], row['q75'], row['max']])

# Use bxp for custom box plot
bp_dicts = []
for i, (pos, data) in enumerate(zip(positions, box_data)):
    bp_dict = {
        'label': stats_df_sorted.iloc[i]['edge_label'],
        'whislo': data[0],  # min
        'q1': data[1],      # 25%
        'med': data[2],     # median
        'q3': data[3],      # 75%
        'whishi': data[4],  # max
        'fliers': []        # no outliers in this representation
    }
    bp_dicts.append(bp_dict)

bp = ax.bxp(bp_dicts, positions=positions, widths=0.6, 
            patch_artist=True, showfliers=False)

# Customize colors
for patch in bp['boxes']:
    patch.set_facecolor('lightblue')
    patch.set_alpha(0.7)

ax.set_xlabel('Edge (sorted by min value)', fontsize=12, fontweight='bold')
ax.set_ylabel('Patristic Distance', fontsize=12, fontweight='bold')
ax.set_title(f'Patristic Distance Distribution Statistics for Graph {target_graph_id}', 
             fontsize=14, fontweight='bold')
ax.set_xticks(positions)
ax.set_xticklabels(stats_df_sorted['edge_label'], rotation=45, ha='right')
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()
